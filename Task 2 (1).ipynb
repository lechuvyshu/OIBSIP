# %% [markdown]
# # OASIS INFOBYTE DATA SCIENCE INTERNSHIP

# %% [markdown]
# ## AUTHOR : VYSHNAVI K.T

# %% [markdown]
# #### TASK 2 : UNEMPLOYMENT ANALYSIS WITH PYTHON

# %% [markdown]
# ##### Importing libraries and data cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ##### Importing the dataset

# %%
df=pd.read_csv('Unemployment_Rate_upto_11_2020[1].csv')
df
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0               16635535                                     41.02    South
# 1               16545652                                     40.90    South
# 2               15881197                                     39.18    South
# 3               11336911                                     33.10    South
# 4               12988845                                     36.46    South
# ..                   ...                                       ...      ...
# 262             30726310                                     40.39     East
# 263             35372506                                     46.17     East
# 264             33298644                                     47.48     East
# 265             35707239                                     47.73     East
# 266             33962549                                     45.63     East
#
#      longitude  latitude
# 0      15.9129    79.740
# 1      15.9129    79.740
# 2      15.9129    79.740
# 3      15.9129    79.740
# 4      15.9129    79.740
# ..         ...       ...
# 262    22.9868    87.855
# 263    22.9868    87.855
# 264    22.9868    87.855
# 265    22.9868    87.855
# 266    22.9868    87.855
#
# [267 rows x 9 columns]

# %% [markdown]
# ##### Exploring the data : Checking the shape, data types, and summary statistics of the dataset

# %%
df.shape
# Out:
# (267, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    267 non-null    object
#  1    Date                                     267 non-null    object
#  2    Frequency                                267 non-null    object
#  3    Estimated Unemployment Rate (%)          267 non-null    float64
#  4    Estimated Employed                       267 non-null    int64
#  5    Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                  267 non-null    object
#  7   longitude                                 267 non-null    float64
#  8   latitude                                  267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %%
df.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        267.000000         2.670000e+02
# mean                          12.236929         1.396211e+07
# std                           10.803283         1.336632e+07
# min                            0.500000         1.175420e+05
# 25%                            4.845000         2.838930e+06
# 50%                            9.650000         9.732417e+06
# 75%                           16.755000         2.187869e+07
# max                           75.850000         5.943376e+07
#
#         Estimated Labour Participation Rate (%)   longitude    latitude
# count                                267.000000  267.000000  267.000000
# mean                                  41.681573   22.826048   80.532425
# std                                    7.845419    6.270731    5.831738
# min                                   16.770000   10.850500   71.192400
# 25%                                   37.265000   18.112400   76.085600
# 50%                                   40.390000   23.610200   79.019300
# 75%                                   44.055000   27.278400   85.279900
# max                                   69.690000   33.778200   92.937600

# %% [markdown]
# ##### Checking for missing values and duplicate rows in the dataset

# %%
df.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Region.1                                    0
# longitude                                   0
# latitude                                    0
# dtype: int64

# %% [markdown]
# ###### No null values in the dataset

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ###### No duplicate values in the dataset

# %% [markdown]
# ##### Checking unique values for States and Region

# %%
df['States'].value_counts()
# Out:
# Andhra Pradesh      10
# Assam               10
# Uttarakhand         10
# Uttar Pradesh       10
# Tripura             10
# Telangana           10
# Tamil Nadu          10
# Rajasthan           10
# Punjab              10
# Puducherry          10
# Odisha              10
# Meghalaya           10
# Maharashtra         10
# Madhya Pradesh      10
# Kerala              10
# Karnataka           10
# Jharkhand           10
# Himachal Pradesh    10
# Haryana             10
# Gujarat             10
# Goa                 10
# Delhi               10
# Chhattisgarh        10
# Bihar               10
# West Bengal         10
# Jammu & Kashmir      9
# Sikkim               8
# Name: States, dtype: int64

# %%
df['Region'].value_counts()
# Out:
# North        79
# South        60
# West         50
# East         40
# Northeast    38
# Name: Region, dtype: int64

# %% [markdown]
# ##### Data Visualization

# %% [markdown]
# ##### Creating a heatmap of the correlation matrix to visualize the relationships between the features

# %%
sns.heatmap(df.corr(),cmap='summer',annot=True)
plt.show()

# %% [markdown]
# ##### Creating a countplot of the 'Region' column to visualize the distribution of the data across regions.

# %%
plt.figure(figsize=(7,7))
sns.countplot(y=df['States'],hue=df['Region'])
plt.show()

# %% [markdown]
# ##### Creating bar plots to visualize the estimated employed, unemployment rate, and labour participation rate for each state.

# %%
plt.figure(figsize=(10,10))
sns.barplot(y="States", x="Estimated Employed",data=df)
plt.show()

# %% [markdown]
# ###### The highest number of people employed is in Uttar Pradesh and the lowest is in Sikkim. The data provided for Sikkim is less compared to other states. This can also be the reason for the decreased number of employed people in that state.

# %%
plt.figure(figsize=(10,10))
sns.barplot(y="States", x="Estimated Unemployment Rate",data=df)
plt.show()

# %% [markdown]
# ###### The highest unemployment is in Haryana, while the lowest is in Meghalaya.

# %%
plt.figure(figsize=(10,10))
sns.barplot(y="States", x="Estimated Labour Participation Rate",data=df)
plt.show()

# %% [markdown]
# ###### The estimated labour participation rate is high in Meghalaya whereas its comparitively low in Kerala. This might be the reason why Meghalaya has lower unemployment rate compared to other states.

# %% [markdown]
# ##### Creating a sunburst chart to visualize the unemployment rate in each region and state.

# %%
ue_df = df[['States', 'Region', 'Estimated Unemployment Rate', 'Estimated Employed', 'Estimated Labour Participation Rate']]
ue = ue_df.groupby(['Region', 'States'])['Estimated Unemployment Rate'].mean().reset_index()
fig = px.sunburst(ue, path=['Region', 'States'], values='Estimated Unemployment Rate',
                  color_continuous_scale='Plasma', title='Unemployment rate in each region and state',
                  height=650, template='ggplot2')
fig.show()

# %% [markdown]
# ###### Conclusion : The heatmap shows that there is a negative correlation between the estimated unemployment rate and the estimated employed. This means that as the number of people employed increases, the unemployment rate decreases. There is also a positive correlation between the estimated unemployment rate and the estimated labour participation rate. This means that as the number of people participating in the labour force increases, the unemployment rate also increases.

# %% [markdown]
# ###### The countplot shows that the most observations in the dataset are from the North region. This is likely due to the fact that the North region has the largest population in India.

# %% [markdown]
# ###### The bar plots show that the state with the highest number of employed people is Uttar Pradesh. The state with the highest unemployment rate is Haryana.
